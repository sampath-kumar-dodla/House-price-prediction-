# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as  plt
import seaborn as sns

# %%
data=pd.read_csv('Delhi house data.csv')

# %%
data
# Out:
#          Area  BHK  Bathroom      Furnishing  \
# 0       800.0    3       2.0  Semi-Furnished
# 1       750.0    2       2.0  Semi-Furnished
# 2       950.0    2       2.0       Furnished
# 3       600.0    2       2.0  Semi-Furnished
# 4       650.0    2       2.0  Semi-Furnished
# ...       ...  ...       ...             ...
# 1254   4118.0    4       5.0     Unfurnished
# 1255   1050.0    3       2.0  Semi-Furnished
# 1256    875.0    3       3.0  Semi-Furnished
# 1257    990.0    2       2.0     Unfurnished
# 1258  11050.0    3       3.0     Unfurnished
#
#                                                Locality  Parking     Price  \
# 0                                      Rohini Sector 25      1.0   6500000
# 1                J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                   Citizen Apartment, Rohini Sector 13      1.0  15500000
# 3                                      Rohini Sector 24      1.0   4200000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Area         1259 non-null   float64
#  1   BHK          1259 non-null   int64
#  2   Bathroom     1257 non-null   float64
#  3   Furnishing   1254 non-null   object
#  4   Locality     1259 non-null   object
#  5   Parking      1226 non-null   float64
#  6   Price        1259 non-null   int64
#  7   Status       1259 non-null   object
#  8   Transaction  1259 non-null   object
#  9   Type         1254 non-null   object
#  10  Per_Sqft     1018 non-null   float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 108.3+ KB

# %%
data.dropna(inplace=True)
data.pop('Locality')
# Out:
# 1                  J R Designers Floors, Rohini Sector 24
# 2                     Citizen Apartment, Rohini Sector 13
# 3                                        Rohini Sector 24
# 4       Rohini Sector 24 carpet area 650 sqft status R...
# 5                                        Rohini Sector 24
#                               ...
# 1254                                    Chittaranjan Park
# 1255                                    Chittaranjan Park
# 1256                                    Chittaranjan Park
# 1257                            Chittaranjan Park Block A
# 1258                                    Chittaranjan Park
# Name: Locality, Length: 1005, dtype: object

# %%
data
# Out:
#          Area  BHK  Bathroom      Furnishing  Parking     Price  \
# 1       750.0    2       2.0  Semi-Furnished      1.0   5000000
# 2       950.0    2       2.0       Furnished      1.0  15500000
# 3       600.0    2       2.0  Semi-Furnished      1.0   4200000
# 4       650.0    2       2.0  Semi-Furnished      1.0   6200000
# 5      1300.0    4       3.0  Semi-Furnished      1.0  15500000
# ...       ...  ...       ...             ...      ...       ...
# 1254   4118.0    4       5.0     Unfurnished      3.0  55000000
# 1255   1050.0    3       2.0  Semi-Furnished      3.0  12500000
# 1256    875.0    3       3.0  Semi-Furnished      3.0  17500000
# 1257    990.0    2       2.0     Unfurnished      1.0  11500000
# 1258  11050.0    3       3.0     Unfurnished      1.0  18500000
#
#              Status   Transaction           Type  Per_Sqft
# 1     Ready_to_move  New_Property      Apartment    6667.0
# 2     Ready_to_move        Resale      Apartment    6667.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1005 entries, 1 to 1258
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Area         1005 non-null   float64
#  1   BHK          1005 non-null   int64
#  2   Bathroom     1005 non-null   float64
#  3   Furnishing   1005 non-null   object
#  4   Parking      1005 non-null   float64
#  5   Price        1005 non-null   int64
#  6   Status       1005 non-null   object
#  7   Transaction  1005 non-null   object
#  8   Type         1005 non-null   object
#  9   Per_Sqft     1005 non-null   float64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 86.4+ KB

# %%
data = data.join(pd.get_dummies(data['Status'], prefix='Status') * 1).drop(['Status'], axis=1)
data = data.join(pd.get_dummies(data['Transaction'], prefix='Transaction') * 1).drop(['Transaction'], axis=1)
data = data.join(pd.get_dummies(data['Type'], prefix='Type') * 1).drop(['Type'], axis=1)
data = data.join(pd.get_dummies(data['Furnishing'], prefix='Furnishing') * 1).drop(['Furnishing'], axis=1)

# %%
data
# Out:
#          Area  BHK  Bathroom  Parking     Price  Per_Sqft  \
# 1       750.0    2       2.0      1.0   5000000    6667.0
# 2       950.0    2       2.0      1.0  15500000    6667.0
# 3       600.0    2       2.0      1.0   4200000    6667.0
# 4       650.0    2       2.0      1.0   6200000    6667.0
# 5      1300.0    4       3.0      1.0  15500000    6667.0
# ...       ...  ...       ...      ...       ...       ...
# 1254   4118.0    4       5.0      3.0  55000000   12916.0
# 1255   1050.0    3       2.0      3.0  12500000   12916.0
# 1256    875.0    3       3.0      3.0  17500000   12916.0
# 1257    990.0    2       2.0      1.0  11500000   12916.0
# 1258  11050.0    3       3.0      1.0  18500000   12916.0
#
#       Status_Almost_ready  Status_Ready_to_move  Transaction_New_Property  \
# 1                       0                     1                         1
# 2                       0                     1                         0
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
x = data.drop(['Price'], axis=1)
y = data['Price']
reg = LinearRegression()
reg.fit(x, y)
# Out:
# LinearRegression()

# %%
x
# Out:
#          Area  BHK  Bathroom  Parking  Per_Sqft  Status_Almost_ready  \
# 1       750.0    2       2.0      1.0    6667.0                    0
# 2       950.0    2       2.0      1.0    6667.0                    0
# 3       600.0    2       2.0      1.0    6667.0                    0
# 4       650.0    2       2.0      1.0    6667.0                    0
# 5      1300.0    4       3.0      1.0    6667.0                    0
# ...       ...  ...       ...      ...       ...                  ...
# 1254   4118.0    4       5.0      3.0   12916.0                    0
# 1255   1050.0    3       2.0      3.0   12916.0                    0
# 1256    875.0    3       3.0      3.0   12916.0                    0
# 1257    990.0    2       2.0      1.0   12916.0                    0
# 1258  11050.0    3       3.0      1.0   12916.0                    0
#
#       Status_Ready_to_move  Transaction_New_Property  Transaction_Resale  \
# ...

# %%
y
# Out:
# 1        5000000
# 2       15500000
# 3        4200000
# 4        6200000
# 5       15500000
#           ...
# 1254    55000000
# 1255    12500000
# 1256    17500000
# 1257    11500000
# 1258    18500000
# Name: Price, Length: 1005, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
train_data = x_train.join(y_train)
test_data = x_test.join(y_test)

# %%
train_data
# Out:
#           Area  BHK  Bathroom  Parking  Per_Sqft  Status_Almost_ready  \
# 715   1200.000    2       2.0      1.0   11538.0                    0
# 64    1050.000    3       2.0      1.0    3524.0                    0
# 368    720.000    3       3.0      2.0    7778.0                    0
# 1235  1070.000    2       3.0      1.0   20938.0                    0
# 1256   875.000    3       3.0      3.0   12916.0                    0
# ...        ...  ...       ...      ...       ...                  ...
# 89    1525.000    3       3.0      1.0    3524.0                    0
# 568   2475.000    4       4.0      1.0   12500.0                    0
# 22     430.556    1       1.0      2.0    6154.0                    0
# 668   2022.000    3       3.0      2.0   18793.0                    0
# 766   1600.000    3       3.0      1.0    3714.0                    0
#
#       Status_Ready_to_move  Transaction_New_Property  Transaction_Resale  \
# ...

# %%
test_data
# Out:
#         Area  BHK  Bathroom  Parking  Per_Sqft  Status_Almost_ready  \
# 1205  2066.0    4       4.0      2.0   30000.0                    1
# 133    900.0    2       2.0      2.0    7000.0                    0
# 135    800.0    2       2.0      1.0    7000.0                    0
# 1157  1500.0    3       3.0      2.0   12500.0                    0
# 997    976.0    2       2.0      2.0   30000.0                    1
# ...      ...  ...       ...      ...       ...                  ...
# 837   1100.0    3       2.0      1.0    7727.0                    0
# 413    550.0    2       1.0      1.0    5794.0                    0
# 168   1000.0    2       2.0      1.0    5255.0                    0
# 621   1350.0    3       3.0      1.0   11111.0                    0
# 917    650.0    3       2.0      3.0   14888.0                    0
#
#       Status_Ready_to_move  Transaction_New_Property  Transaction_Resale  \
# 1205                     0                         1                   0
# ...

# %%
train_data.hist(figsize=(17,12))
# Out:
# array([[<Axes: title={'center': 'Area'}>,
#         <Axes: title={'center': 'BHK'}>,
#         <Axes: title={'center': 'Bathroom'}>,
#         <Axes: title={'center': 'Parking'}>],
#        [<Axes: title={'center': 'Per_Sqft'}>,
#         <Axes: title={'center': 'Status_Almost_ready'}>,
#         <Axes: title={'center': 'Status_Ready_to_move'}>,
#         <Axes: title={'center': 'Transaction_New_Property'}>],
#        [<Axes: title={'center': 'Transaction_Resale'}>,
#         <Axes: title={'center': 'Type_Apartment'}>,
#         <Axes: title={'center': 'Type_Builder_Floor'}>,
#         <Axes: title={'center': 'Furnishing_Furnished'}>],
#        [<Axes: title={'center': 'Furnishing_Semi-Furnished'}>,
#         <Axes: title={'center': 'Furnishing_Unfurnished'}>,
#         <Axes: title={'center': 'Price'}>, <Axes: >]], dtype=object)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
reg.score(x_test, y_test)
# Out:
# 0.6551929687536829

# %%
from sklearn.ensemble import RandomForestRegressor
forest = RandomForestRegressor()
forest.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test, y_test)
# Out:
# 0.799991440178056
